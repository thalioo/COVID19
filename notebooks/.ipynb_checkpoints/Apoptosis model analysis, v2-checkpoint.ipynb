# %%
import maboss

# %%
model = maboss.load(
    "epithelial_cell.bnd", 
    "epithelial_cell.cfg"
)

# %% [markdown]
# ### Drawing the interaction graph

# %%
mini_model = maboss.to_minibn(model)

# %%
mini_model.influence_graph()
# Out:
# # computing graph layout...

# %% [markdown]
# ### Type 2 type simulation

# %%
res1 = model_tcell.run()
res1.plot_piechart()
# Out:
# /home/vincent/.conda/envs/exastolog/lib/python3.7/site-packages/maboss/figures.py:87: MatplotlibDeprecationWarning: normalize=None does not normalize if the sum is less than 1 but this behavior is deprecated since 3.3 until two minor releases later. After the deprecation period the default value will be normalize=True. To prevent normalization pass normalize=False
#   startangle=90, colors=color_list, **opts)

# %% [markdown]
# ### TNF simulation

# %%
model_tnf = model.copy()
model_tnf.network.set_istate(
    'TNF_TNFRSF1A_complex', [0, 1]
)

# %%
res_tnf = model_tnf.run()
res_tnf.plot_piechart()

# %% [markdown]
# ### FASL simulation

# %%
model_fasl = model.copy()
model_fasl.network.set_istate('FAS_FASL_complex', [0, 1])

# %%
res_fasl = model_fasl.run()
res_fasl.plot_piechart()

# %%
res_fasl.plot_trajectory()

# %% [markdown]
# ### TNF + FASL simulation

# %%
model_tnf_fasl = model.copy()
model_tnf_fasl.network.set_istate('TNF_TNFRSF1A_complex', [0, 1])
model_tnf_fasl.network.set_istate('FAS_FASL_complex', [0, 1])

# %%
res_tnf_fasl = model_tnf_fasl.run()
res_tnf_fasl.plot_piechart()

# %% [markdown]
# ### Virus_inside simulation

# %%
model_virus = model.copy()
model_virus.network.set_istate('Virus_inside', [0, 1])

# %%
res_virus = model_virus.run()
res_virus.plot_piechart()

# %%
res_virus.plot_trajectory()
